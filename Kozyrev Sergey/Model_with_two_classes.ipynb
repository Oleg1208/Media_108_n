# %%
import pandas as pd
import time
from tensorflow.keras.utils import to_categorical
import numpy as np
import random
import zipfile
import os
import shutil
from google.colab import files
import librosa                            # Параметризация аудио
import librosa.display                    # Визуализация аудио
import matplotlib.pyplot as plt           # Отрисовка графиков
import IPython.display as ipd             # Проигрывание аудио в colab
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import pickle
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import concatenate, Input, Dense, Dropout, BatchNormalization, Flatten, Conv1D, Conv2D, LSTM
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Нормирование сигнала
from sklearn.preprocessing import minmax_scale, scale

# %matplotlib inline

# %%
def handle_outliers_in_csv(collection, base_path):
    csv_path = os.path.join(base_path, f"{collection}.csv")

    expected_fields = {
        'Headliner': 72,
        'Primavera': 74,
        'Paveletskaya': 74
    }.get(collection, 74)  # default to 74 fields

    with open(csv_path, 'r') as data:
        corrected_data = []
        corrections_made = False
        modified_lines = 0
        for n, string in enumerate(data):
            list_string = string.split(';')
            if len(list_string) > expected_fields:
                corrections_made = True
                modified_lines += 1
                print(f"Линия {n + 1}: Найдено {len(list_string)} колонок. Ожидалось {expected_fields}.")
                list_string = list_string[:expected_fields]
                corrected_data.append(';'.join(list_string))
            else:
                corrected_data.append(string.rstrip())

    if corrections_made:
        corrected_csv_path = os.path.join(base_path, f"{collection}_without_outlier.csv")
        with open(corrected_csv_path, 'w') as new_data:
            new_data.write('\n'.join(corrected_data))
        print(f"Общее количество линий модифицировано для {collection}: {modified_lines}")

# %%
handle_outliers_in_csv("Headliner", "/content/drive/MyDrive/Phone_calls/V3")

# %%
handle_outliers_in_csv("Primavera", "/content/drive/MyDrive/Phone_calls/V3")

# %%
handle_outliers_in_csv("Paveletskaya", "/content/drive/MyDrive/Phone_calls/V3")

# %%
def process_collection_with_patterns(collection, patterns, base_path):
    csv_path = os.path.join(base_path, f"{collection}_without_outlier.csv")
    zip_path = os.path.join(base_path, f"{collection}.zip")

    df = pd.read_csv(csv_path, delimiter=';', on_bad_lines='warn')

    # Handle target patterns
    for pattern in patterns:
        extract_folder = os.path.join(base_path, f"filtered_files_{pattern}_{collection}")
        dest_dir = os.path.join(base_path, 'data', pattern_to_folder(pattern))
        filtered_df = df[df["Теги"].str.contains(pattern, na=False, regex=True)]

        if not filtered_df.empty:
            process_filtered_data(filtered_df, extract_folder, dest_dir, zip_path, pattern, collection)

    # Handle non-target patterns
    non_targets_df = df[~df["Теги"].str.contains('|'.join(patterns), na=False, regex=True)]
    if not non_targets_df.empty:
        extract_folder = os.path.join(base_path, f"filtered_files_nontargets_{collection}")
        dest_dir = os.path.join(base_path, 'data', 'nontargets')
        process_filtered_data(non_targets_df, extract_folder, dest_dir, zip_path, "nontargets", collection)

def process_filtered_data(filtered_df, extract_folder, dest_dir, zip_path, pattern, collection):
    if not os.path.exists(extract_folder):
        os.makedirs(extract_folder)
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    result_df = filtered_df[["Теги", "Идентификатор сессии звонка"]]
    result_csv_path = os.path.join(extract_folder, f"Filtered_tags_{pattern}_{collection}.csv")
    result_df.to_csv(result_csv_path, index=False)

    extract_and_copy_files(filtered_df, zip_path, extract_folder, dest_dir)

def extract_and_copy_files(df, zip_path, extract_folder, dest_dir):
    identifiers = df['Идентификатор сессии звонка'].tolist()

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        matched_files = 0
        missing_identifiers = []

        for identifier in identifiers:
            matched = False
            for file in zip_ref.namelist():
                if str(identifier) in file:
                    zip_ref.extract(file, extract_folder)
                    os.rename(os.path.join(extract_folder, file), os.path.join(extract_folder, f"{identifier}.mp3"))
                    matched = True
                    matched_files += 1
                    break
            if not matched:
                missing_identifiers.append(identifier)

        print(f"Total matches: {matched_files}")
        print(f"Missing audio records total: {len(missing_identifiers)} and list: {missing_identifiers}")

    copy_mp3_files(extract_folder, dest_dir)
    total_files = len([f for f in os.listdir(dest_dir) if os.path.isfile(os.path.join(dest_dir, f))])
    print(f"Total files in {dest_dir}: {total_files}")

def copy_mp3_files(src_dir, dest_dir):
    for filename in os.listdir(src_dir):
        if filename.endswith('.mp3'):
            shutil.copy(os.path.join(src_dir, filename), dest_dir)

def pattern_to_folder(pattern):
    mapping = {
        'Первичный целевой': 'targets',
        'Целевой_М108': 'targets',
    }
    return mapping.get(pattern, 'unknown')

# %%
process_collection_with_patterns('Headliner', ['Первичный целевой'], '/content/drive/MyDrive/Phone_calls/V3')

# %%
process_collection_with_patterns('Primavera', ['Целевой_М108'], '/content/drive/MyDrive/Phone_calls/V3')

# %%
process_collection_with_patterns('Paveletskaya', ['Целевой_М108'], '/content/drive/MyDrive/Phone_calls/V3')

# %%
classes = ['nontargets', 'targets']
for eachclass in classes:
  total_files = len([f for f in os.listdir(f'/content/drive/MyDrive/Phone_calls/V3/data/{eachclass}') if os.path.isfile(os.path.join(f'/content/drive/MyDrive/Phone_calls/V3/data/{eachclass}', f))])
  print(f"Общее количество файлов в классе {eachclass}: {total_files}")
# Out:
# Общее количество файлов в классе nontargets: 1069
# Общее количество файлов в классе targets: 1204

# %%
# Функция загрузки аудио и вывода текстовой информации
# о сигнале, а также проигрывателя аудио

def load_audio(audio_path,       # путь к файлу с аудио
               show_text=True,   # показывать ли текстовую сводку по аудио
               show_player=True  # выводить ли проигрыватель в ячейку
               ):
    # Загрузка аудиофайла, на выходе:
    # x  - массив данных временного ряда аудио
    # sr - частота дискретизации временного ряда
    x, sr = librosa.load(audio_path)

    if show_text:
        # Вывод текстовых данных о сигнале
        print(f'Типы данных x и sr: {type(x)}, {type(sr)}')
        print(f'Форма данных x: {x.shape}, sr = {sr}')
        print('Продолжительность сигнала:', round(x.shape[0]/sr), 'с.\n')

    if show_player:
        # Вывод проигрывателя в ячейку colab
        ipd.display(ipd.Audio(audio_path))

    # Возврат загруженных данных для дальнейшего использования
    return x, sr

# %%
directory_path = '/content/drive/MyDrive/Phone_calls/V3/data/targets'
counter = 0
for filename in os.listdir(directory_path):
    if filename.endswith('.mp3'):
        file_path = os.path.join(directory_path, filename)
        x, sr = load_audio(file_path, show_text=False, show_player=False)
        duration = len(x) / sr
        if duration < 75:
            os.remove(file_path)
            # print(f"Deleted {filename} due to short duration.")
            counter += 1
print(f'Файлов удалено: {counter}')
# Out:
# Файлов удалено: 103

# %%
directory_path = '/content/drive/MyDrive/Phone_calls/V3/data/nontargets'
counter = 0
for filename in os.listdir(directory_path):
    if filename.endswith('.mp3'):
        file_path = os.path.join(directory_path, filename)
        x, sr = load_audio(file_path, show_text=False, show_player=False)
        duration = len(x) / sr
        if duration < 75:
            os.remove(file_path)
            # print(f"Deleted {filename} due to short duration.")
            counter += 1
print(f'Файлов удалено: {counter}')
# Out:
# Файлов удалено: 2178

# %%
classes = ['nontargets', 'targets']
for eachclass in classes:
  total_files = len([f for f in os.listdir(f'/content/drive/MyDrive/Phone_calls/V3/data/{eachclass}') if os.path.isfile(os.path.join(f'/content/drive/MyDrive/Phone_calls/V3/data/{eachclass}', f))])
  print(f"Общее количество файлов в классе {eachclass}: {total_files}")
# Out:
# Общее количество файлов в классе nontargets: 1069
# Общее количество файлов в классе targets: 1204

# %%
def copy_random_files(base_path, class_name, target_count):
    class_folder = os.path.join(base_path, 'data', class_name)
    new_folder = os.path.join(base_path, 'subset_data', f"{class_name}")

    if not os.path.exists(new_folder):
        os.makedirs(new_folder)

    file_list = [f for f in os.listdir(class_folder) if os.path.isfile(os.path.join(class_folder, f))]

    selected_files = random.sample(file_list, target_count)

    for filename in selected_files:
        source = os.path.join(class_folder, filename)
        destination = os.path.join(new_folder, filename)
        shutil.copy2(source, destination)

    print(f"Скопировано {target_count} рандомных файлов из {class_folder} в {new_folder}.")
    print(f"Общее количество файлов в {new_folder}: {len(os.listdir(new_folder))}")

# %%
base_path = '/content/drive/MyDrive/Phone_calls/V3'
target_count = 1069

copy_random_files(base_path, 'nontargets', target_count)
copy_random_files(base_path, 'targets', target_count)
# Out:
# Скопировано 1069 рандомных файлов из /content/drive/MyDrive/Phone_calls/V3/data/nontargets в /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets.
# Общее количество файлов в /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets: 1069
# Скопировано 1069 рандомных файлов из /content/drive/MyDrive/Phone_calls/V3/data/targets в /content/drive/MyDrive/Phone_calls/V3/subset_data/targets.
# Общее количество файлов в /content/drive/MyDrive/Phone_calls/V3/subset_data/targets: 1069

# %%
nontargets_data = os.listdir('/content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets')
targets_data = os.listdir('/content/drive/MyDrive/Phone_calls/V3/subset_data/targets')
print(f'nontargets length: {len(nontargets_data)}')
print(f'targets length: {len(targets_data)}')
# Out:
# nontargets length: 1069
# targets length: 1069

# %%
FILE_DIR = '/content/drive/MyDrive/Phone_calls/V3/subset_data'
CLASS_LIST = os.listdir(FILE_DIR)
CLASS_LIST.sort()
CLASS_COUNT = len(CLASS_LIST)
CLASS_FILES = 1069                         # Общее количество файлов в каждом классе
FILE_INDEX_TRAIN_SPLIT = 962               # Количество файлов каждого класса на основной набор
VALIDATION_SPLIT = 0.1                    # Доля проверочной выборки в основном наборе
DURATION_SEC = 300                         # Анализируемая длительность аудиосигнала
N_FFT = 4096                              # Размер окна преобразования Фурье для расчета спектра
HOP_LENGTH = 512                          # Объем данных для расчета одного набора признаков

# %%
print(CLASS_LIST)
# Out:
# ['nontargets', 'targets']

# %%
# Функция параметризации аудио

def get_features(y,                     # волновое представление сигнала
                 sr,                    # частота дискретизации сигнала y
                 n_fft=N_FFT,           # размер скользящего окна БПФ
                 hop_length=HOP_LENGTH  # шаг скользящего окна БПФ
                 ):
    # Вычисление различных параметров (признаков) аудио

    # Среднеквадратическая амплитуда
    rmse = librosa.feature.rms(y=y, hop_length=hop_length)
    # Спектральный центроид
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Ширина полосы частот
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Спектральный спад частоты
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Пересечения нуля
    zcr = librosa.feature.zero_crossing_rate(y, hop_length=hop_length)
    # Мел-кепстральные коэффициенты
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Хромаграмма
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)

    # Сборка параметров в общий список:
    # На один файл один усредненный вектор признаков
    features = {'rmse': rmse.mean(axis=1, keepdims=True),
                'spct': spec_cent.mean(axis=1, keepdims=True),
                'spbw': spec_bw.mean(axis=1, keepdims=True),
                'roff': rolloff.mean(axis=1, keepdims=True),
                'zcr' : zcr.mean(axis=1, keepdims=True),
                'mfcc': mfcc.mean(axis=1, keepdims=True),
                'stft': chroma_stft.mean(axis=1, keepdims=True)}

    return features

# %%
# Функция объединения признаков в набор векторов

def stack_features(feat  # словарь признаков, отдельные векторы по ключу каждого признака
                   ):
    features = None
    for v in feat.values():
        features = np.vstack((features, v)) if features is not None else v

    return features.T

# %%
# Проверка параметризации одного произведения
y, sr = librosa.load(f'{FILE_DIR}/targets/2906114070.mp3', mono=True, duration=DURATION_SEC)
features = get_features(y, sr)

# %%
print({k: v.shape for k, v in features.items()})
# Out:
# {'rmse': (1, 1), 'spct': (1, 1), 'spbw': (1, 1), 'roff': (1, 1), 'zcr': (1, 1), 'mfcc': (20, 1), 'stft': (12, 1)}

# %%
# Проверка формирования набора признаков
feature_set = stack_features(features)
feature_set.shape
# Out:
# (1, 37)

# %%
# Функция формирования набора признаков и метки класса для аудиофайла

def get_feature_list_from_file(class_index,  # индекс класса файла song_name
                               song_name,    # имя аудиофайла
                               duration_sec  # длительность аудио в секундах
                               ):
    # Загрузка в y первых duration_sec секунд аудиосигнала
    y, sr = librosa.load(song_name, mono=True, duration=duration_sec)

    # Извлечение параметров из аудиосигнала
    features = get_features(y, sr)
    feature_set = stack_features(features)

    # Перевод номера класса в one hot encoding
    y_label = to_categorical(class_index, CLASS_COUNT)

    return feature_set, y_label

# %%
# Функция формирования подвыборки признаков и меток класса для одного файла

def process_file(class_index,  # индекс класса аудиофайла
                 file_index,   # индекс (порядковый номер) аудиофайла в папке класса
                 duration_sec  # длительность аудио в секундах
                 ):
    x_list = []
    y_list = []
    class_name = CLASS_LIST[class_index]

    if class_name == "nontargets":
        file_name = nontargets_data[file_index]
    elif class_name == "secondarytargets":
        file_name = secondtargets_data[file_index]
    elif class_name == "targets":
        file_name = targets_data[file_index]
    else:
        raise ValueError(f"Unknown class name: {class_name}")
    # Извлечение имени произведения
    song_name = f'{FILE_DIR}/{class_name}/{file_name}'

    # Выборка признаков и метки класса для произведения
    feature_set, y_label = get_feature_list_from_file(class_index,
                                                        song_name,
                                                        duration_sec)

    # Добавление данных в наборы
    for j in range(feature_set.shape[0]):
        x_list.append(feature_set[j])
        y_list.append(y_label)

    # Возврат имени файла и numpy-массивов призанков и меток класса
    return song_name, \
           np.array(x_list).astype('float32'), \
           np.array(y_list).astype('float32')

# %%
# Функция формирования набора данных из файлов всех классов по диапазону номеров файлов

def extract_data(file_index_start,          # начальный индекс аудиофайла
                 file_index_end,            # конечный индекс аудиофайла (не достигая)
                 duration_sec=DURATION_SEC  # длительность аудио в секундах
                 ):

    # Списки для последовательностей входных данных и меток класса
    x_data = None
    y_data = None

    # Фиксация времени старта формирования выборки
    curr_time = time.time()

    # Для всех классов:
    for class_index in range(len(CLASS_LIST)):
        # Для всех файлов текущего класса из заданного диапазона номеров:
        for file_index in range(file_index_start, file_index_end):
            # Обработка одного файла и добавление данных к общим массивам
            _, file_x_data, file_y_data = process_file(class_index, file_index, duration_sec)
            x_data = file_x_data if x_data is None else np.vstack([x_data, file_x_data])
            y_data = file_y_data if y_data is None else np.vstack([y_data, file_y_data])
            # print(f'Жанр {CLASS_LIST[class_index]} - файл {file_index} готов -> {round(time.time() - curr_time)} c')

        # Вывод информации о готовности обработки датасета
        print(f'Жанр {CLASS_LIST[class_index]} готов -> {round(time.time() - curr_time)} c')
        curr_time = time.time()

    # Возврат массивов набора данных
    return x_data, y_data

# %%
x_train_data, y_train_data = extract_data(0, FILE_INDEX_TRAIN_SPLIT)
# Out:
# Жанр nontargets готов -> 6328 c
# Жанр targets готов -> 7994 c

# %%
import pickle
# Сохранение/восстановление датасета аудио
# Данные привязаны к порядку следования меток классов!
# Порядок классов фиксирован сортировкой списка меток классов
with open('/content/drive/MyDrive/Phone_calls/V3/subset_data/audio_data_mean.pickle', 'wb') as f:
    pickle.dump((x_train_data, y_train_data), f)

# %%
with open('/content/drive/MyDrive/Phone_calls/V2/model_data/audio_data_mean.pickle', 'rb') as f:
    x_train_data, y_train_data = pickle.load(f)

# %%
print(np.argmax(y_train_data[1920:], axis=1))
# Out:
# [1 1 1 1]

# %%
# Вывод формы данных обучающего набора
print(x_train_data.shape, x_train_data.dtype)
print(y_train_data.shape, y_train_data.dtype)
# Out:
# (1924, 37) float32
# (1924, 2) float32

# %%
# Нормирование признаков в соответствии со стандартным нормальным распределением
x_scaler = StandardScaler()
x_train_data_scaled = x_scaler.fit_transform(x_train_data)

# %%
# Разделение набора данных на обучающую и проверочную выборки
# Параметр stratify указывает метки классов, по которым происходит балансировка разделения
x_train, x_val, y_train, y_val = train_test_split(x_train_data_scaled,
                                                  y_train_data,
                                                  stratify=y_train_data,
                                                  test_size=VALIDATION_SPLIT)

# %%
# Проверка нормирования
print(x_train[0])
# Out:
# [ 2.48940632e-01 -3.33269328e-01 -9.10510272e-02 -5.62519133e-02
#  -3.49018604e-01  4.58810449e-01  9.13844824e-01 -5.55526853e-01
#  -6.95522651e-02  4.12195027e-01 -9.75284815e-01 -4.60556239e-01
#   1.47044134e+00  5.46542406e-01 -9.46849704e-01 -2.23668575e-01
#   3.42016041e-01  3.89474990e-05  5.38518727e-01  8.95685911e-01
#   1.20665856e-01  2.22474542e-02  7.86188990e-02 -7.40967095e-01
#  -1.01505113e+00 -1.03047061e+00 -1.15953553e+00 -1.36786747e+00
#  -2.08666945e+00 -2.34547019e+00 -2.09358001e+00 -1.50016308e+00
#  -5.67562282e-01 -1.24858588e-01  1.72314838e-01  1.15567885e-01
#  -4.83150601e-01]

# %%
# Проверка формы и типа данных обучающей и проверочной выборок
print(x_train.shape, x_train.dtype)
print(y_train.shape, y_train.dtype)
print()
print(x_val.shape, x_val.dtype)
print(y_val.shape, y_val.dtype)
# Out:
# (1731, 37) float32
# (1731, 2) float32
#
# (193, 37) float32
# (193, 2) float32

# %%
# Проверка сбалансированности выборок по классам
plt.hist(np.argmax(y_train, axis=1), CLASS_COUNT)
plt.hist(np.argmax(y_val, axis=1), CLASS_COUNT)
plt.show()

# %%
# Функция сборки и обучения классификатора на полносвязных слоях

def create_train_classifier(in_shape,      # форма входных данных модели
                            epochs=200,    # количество эпох обучения
                            batch_size=20  # размер батча
                            ):
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=in_shape))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(Dense(CLASS_COUNT, activation='softmax'))

    # Компиляция модели
    model.compile(optimizer=Adam(lr=1e-4),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

    model.summary()

    # Обучение модели
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Вывод графика точности распознавания на обучающей и проверочной выборках
    plt.figure(figsize=(12, 5))
    plt.plot(history.history['accuracy'], label='Точность на обучающем наборе')
    plt.plot(history.history['val_accuracy'], label='Точность на проверочном наборе')
    plt.xticks(range(0, epochs, 10))
    plt.xlabel('Эпоха')
    plt.ylabel('Точность')
    plt.legend()
    plt.show()

    return model

# %%
model = create_train_classifier(x_train.shape[1:])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 256)               9728
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  batch_normalization_6 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  batch_normalization_7 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_11 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 52802 (206.26 KB)
# Trainable params: 51906 (202.76 KB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________
# Epoch 1/200
# 87/87 [==============================] - 3s 6ms/step - loss: 0.8531 - accuracy: 0.5748 - val_loss: 0.6383 - val_accuracy: 0.6477
# Epoch 2/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.7099 - accuracy: 0.6205 - val_loss: 0.6179 - val_accuracy: 0.7098
# Epoch 3/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.6831 - accuracy: 0.6291 - val_loss: 0.6006 - val_accuracy: 0.7150
# Epoch 4/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.6597 - accuracy: 0.6424 - val_loss: 0.5810 - val_accuracy: 0.7306
# Epoch 5/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.6144 - accuracy: 0.6730 - val_loss: 0.5736 - val_accuracy: 0.7254
# Epoch 6/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.6231 - accuracy: 0.6476 - val_loss: 0.5729 - val_accuracy: 0.7306
# Epoch 7/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.6771 - val_loss: 0.5703 - val_accuracy: 0.7202
# Epoch 8/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5933 - accuracy: 0.6788 - val_loss: 0.5606 - val_accuracy: 0.7202
# Epoch 9/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5818 - accuracy: 0.6909 - val_loss: 0.5770 - val_accuracy: 0.7098
# Epoch 10/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5702 - accuracy: 0.7025 - val_loss: 0.5764 - val_accuracy: 0.7047
# Epoch 11/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5828 - accuracy: 0.6967 - val_loss: 0.5689 - val_accuracy: 0.6943
# Epoch 12/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5598 - accuracy: 0.6990 - val_loss: 0.5809 - val_accuracy: 0.7098
# Epoch 13/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5633 - accuracy: 0.7013 - val_loss: 0.5833 - val_accuracy: 0.6995
# Epoch 14/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5575 - accuracy: 0.7106 - val_loss: 0.5728 - val_accuracy: 0.6943
# Epoch 15/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5606 - accuracy: 0.7135 - val_loss: 0.5610 - val_accuracy: 0.6736
# Epoch 16/200
# 87/87 [==============================] - 0s 6ms/step - loss: 0.5320 - accuracy: 0.7291 - val_loss: 0.5694 - val_accuracy: 0.6943
# Epoch 17/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5513 - accuracy: 0.7123 - val_loss: 0.5694 - val_accuracy: 0.6839
# Epoch 18/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5396 - accuracy: 0.7302 - val_loss: 0.5671 - val_accuracy: 0.6736
# Epoch 19/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5447 - accuracy: 0.7140 - val_loss: 0.5792 - val_accuracy: 0.6995
# Epoch 20/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5336 - accuracy: 0.7244 - val_loss: 0.5654 - val_accuracy: 0.6788
# Epoch 21/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5266 - accuracy: 0.7279 - val_loss: 0.5470 - val_accuracy: 0.7098
# Epoch 22/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5181 - accuracy: 0.7412 - val_loss: 0.5868 - val_accuracy: 0.6891
# Epoch 23/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5175 - accuracy: 0.7452 - val_loss: 0.5886 - val_accuracy: 0.7098
# Epoch 24/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.5285 - accuracy: 0.7360 - val_loss: 0.5904 - val_accuracy: 0.6684
# Epoch 25/200
# 87/87 [==============================] - 1s 8ms/step - loss: 0.5065 - accuracy: 0.7470 - val_loss: 0.5779 - val_accuracy: 0.6995
# Epoch 26/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5142 - accuracy: 0.7389 - val_loss: 0.5768 - val_accuracy: 0.6891
# Epoch 27/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5113 - accuracy: 0.7447 - val_loss: 0.5968 - val_accuracy: 0.6891
# Epoch 28/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5052 - accuracy: 0.7470 - val_loss: 0.6089 - val_accuracy: 0.6943
# Epoch 29/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.5003 - accuracy: 0.7620 - val_loss: 0.6041 - val_accuracy: 0.6891
# Epoch 30/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.4899 - accuracy: 0.7626 - val_loss: 0.6022 - val_accuracy: 0.6891
# Epoch 31/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.4934 - accuracy: 0.7556 - val_loss: 0.5985 - val_accuracy: 0.6684
# Epoch 32/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4889 - accuracy: 0.7747 - val_loss: 0.6291 - val_accuracy: 0.6736
# Epoch 33/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4892 - accuracy: 0.7597 - val_loss: 0.5917 - val_accuracy: 0.6788
# Epoch 34/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5001 - accuracy: 0.7626 - val_loss: 0.6224 - val_accuracy: 0.6684
# Epoch 35/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4746 - accuracy: 0.7666 - val_loss: 0.6099 - val_accuracy: 0.6684
# Epoch 36/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4731 - accuracy: 0.7626 - val_loss: 0.6040 - val_accuracy: 0.6736
# Epoch 37/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4740 - accuracy: 0.7782 - val_loss: 0.5908 - val_accuracy: 0.6788
# Epoch 38/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4847 - accuracy: 0.7597 - val_loss: 0.6013 - val_accuracy: 0.6839
# Epoch 39/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4768 - accuracy: 0.7608 - val_loss: 0.6170 - val_accuracy: 0.6788
# Epoch 40/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4635 - accuracy: 0.7770 - val_loss: 0.6702 - val_accuracy: 0.6839
# Epoch 41/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4591 - accuracy: 0.7909 - val_loss: 0.6551 - val_accuracy: 0.6839
# Epoch 42/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4619 - accuracy: 0.7701 - val_loss: 0.6351 - val_accuracy: 0.6839
# Epoch 43/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4692 - accuracy: 0.7741 - val_loss: 0.6556 - val_accuracy: 0.6943
# Epoch 44/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4716 - accuracy: 0.7799 - val_loss: 0.6304 - val_accuracy: 0.6891
# Epoch 45/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4686 - accuracy: 0.7793 - val_loss: 0.6337 - val_accuracy: 0.6891
# Epoch 46/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4670 - accuracy: 0.7811 - val_loss: 0.6046 - val_accuracy: 0.6891
# Epoch 47/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4665 - accuracy: 0.7741 - val_loss: 0.5957 - val_accuracy: 0.6632
# Epoch 48/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4502 - accuracy: 0.7972 - val_loss: 0.6412 - val_accuracy: 0.6943
# Epoch 49/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4569 - accuracy: 0.7834 - val_loss: 0.6494 - val_accuracy: 0.6528
# Epoch 50/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4474 - accuracy: 0.7776 - val_loss: 0.6433 - val_accuracy: 0.6684
# Epoch 51/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4539 - accuracy: 0.7949 - val_loss: 0.6455 - val_accuracy: 0.6891
# Epoch 52/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.4382 - accuracy: 0.7966 - val_loss: 0.6534 - val_accuracy: 0.6632
# Epoch 53/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.4379 - accuracy: 0.7932 - val_loss: 0.6890 - val_accuracy: 0.6632
# Epoch 54/200
# 87/87 [==============================] - 0s 6ms/step - loss: 0.4289 - accuracy: 0.8105 - val_loss: 0.6796 - val_accuracy: 0.6788
# Epoch 55/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.4335 - accuracy: 0.8018 - val_loss: 0.6987 - val_accuracy: 0.6373
# Epoch 56/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.4311 - accuracy: 0.8024 - val_loss: 0.6939 - val_accuracy: 0.6788
# Epoch 57/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.4371 - accuracy: 0.7920 - val_loss: 0.7059 - val_accuracy: 0.6736
# Epoch 58/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.4362 - accuracy: 0.7874 - val_loss: 0.6463 - val_accuracy: 0.6891
# Epoch 59/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.4222 - accuracy: 0.7995 - val_loss: 0.6534 - val_accuracy: 0.6788
# Epoch 60/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.4248 - accuracy: 0.8065 - val_loss: 0.6372 - val_accuracy: 0.6995
# Epoch 61/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.4351 - accuracy: 0.7897 - val_loss: 0.6095 - val_accuracy: 0.6736
# Epoch 62/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.4192 - accuracy: 0.8076 - val_loss: 0.6206 - val_accuracy: 0.6736
# Epoch 63/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4137 - accuracy: 0.8094 - val_loss: 0.6556 - val_accuracy: 0.6736
# Epoch 64/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4177 - accuracy: 0.8047 - val_loss: 0.6688 - val_accuracy: 0.6839
# Epoch 65/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4121 - accuracy: 0.8059 - val_loss: 0.6673 - val_accuracy: 0.6736
# Epoch 66/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3927 - accuracy: 0.8111 - val_loss: 0.6652 - val_accuracy: 0.6736
# Epoch 67/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4025 - accuracy: 0.8134 - val_loss: 0.6924 - val_accuracy: 0.6632
# Epoch 68/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4195 - accuracy: 0.8013 - val_loss: 0.6771 - val_accuracy: 0.6943
# Epoch 69/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4209 - accuracy: 0.8169 - val_loss: 0.6475 - val_accuracy: 0.6528
# Epoch 70/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3867 - accuracy: 0.8278 - val_loss: 0.6721 - val_accuracy: 0.6736
# Epoch 71/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3994 - accuracy: 0.8169 - val_loss: 0.6963 - val_accuracy: 0.6736
# Epoch 72/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3931 - accuracy: 0.8273 - val_loss: 0.6667 - val_accuracy: 0.6788
# Epoch 73/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3923 - accuracy: 0.8290 - val_loss: 0.6627 - val_accuracy: 0.6839
# Epoch 74/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3877 - accuracy: 0.8250 - val_loss: 0.6990 - val_accuracy: 0.6891
# Epoch 75/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.8070 - val_loss: 0.6374 - val_accuracy: 0.6736
# Epoch 76/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3909 - accuracy: 0.8180 - val_loss: 0.6255 - val_accuracy: 0.7047
# Epoch 77/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3732 - accuracy: 0.8290 - val_loss: 0.6815 - val_accuracy: 0.7150
# Epoch 78/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3962 - accuracy: 0.8140 - val_loss: 0.6427 - val_accuracy: 0.6943
# Epoch 79/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3811 - accuracy: 0.8359 - val_loss: 0.6576 - val_accuracy: 0.6891
# Epoch 80/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3884 - accuracy: 0.8261 - val_loss: 0.6323 - val_accuracy: 0.7047
# Epoch 81/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3795 - accuracy: 0.8261 - val_loss: 0.6411 - val_accuracy: 0.6736
# Epoch 82/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3808 - accuracy: 0.8261 - val_loss: 0.6894 - val_accuracy: 0.6943
# Epoch 83/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3711 - accuracy: 0.8348 - val_loss: 0.6858 - val_accuracy: 0.6891
# Epoch 84/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3865 - accuracy: 0.8261 - val_loss: 0.6407 - val_accuracy: 0.6788
# Epoch 85/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3736 - accuracy: 0.8261 - val_loss: 0.6536 - val_accuracy: 0.6891
# Epoch 86/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3791 - accuracy: 0.8250 - val_loss: 0.6701 - val_accuracy: 0.6788
# Epoch 87/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3810 - accuracy: 0.8302 - val_loss: 0.6675 - val_accuracy: 0.6684
# Epoch 88/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3802 - accuracy: 0.8307 - val_loss: 0.7053 - val_accuracy: 0.6891
# Epoch 89/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3581 - accuracy: 0.8452 - val_loss: 0.6976 - val_accuracy: 0.6477
# Epoch 90/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3537 - accuracy: 0.8388 - val_loss: 0.7341 - val_accuracy: 0.6736
# Epoch 91/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3498 - accuracy: 0.8492 - val_loss: 0.6998 - val_accuracy: 0.6943
# Epoch 92/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.3633 - accuracy: 0.8440 - val_loss: 0.7161 - val_accuracy: 0.7098
# Epoch 93/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3770 - accuracy: 0.8284 - val_loss: 0.7076 - val_accuracy: 0.6736
# Epoch 94/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3627 - accuracy: 0.8325 - val_loss: 0.7081 - val_accuracy: 0.6684
# Epoch 95/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3697 - accuracy: 0.8290 - val_loss: 0.6964 - val_accuracy: 0.6632
# Epoch 96/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3578 - accuracy: 0.8296 - val_loss: 0.6860 - val_accuracy: 0.6839
# Epoch 97/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3643 - accuracy: 0.8377 - val_loss: 0.6845 - val_accuracy: 0.6632
# Epoch 98/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3539 - accuracy: 0.8423 - val_loss: 0.6739 - val_accuracy: 0.6839
# Epoch 99/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3461 - accuracy: 0.8423 - val_loss: 0.6882 - val_accuracy: 0.6839
# Epoch 100/200
# 87/87 [==============================] - 0s 6ms/step - loss: 0.3552 - accuracy: 0.8544 - val_loss: 0.6821 - val_accuracy: 0.7254
# Epoch 101/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3450 - accuracy: 0.8486 - val_loss: 0.6804 - val_accuracy: 0.6632
# Epoch 102/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3467 - accuracy: 0.8486 - val_loss: 0.7289 - val_accuracy: 0.6891
# Epoch 103/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3333 - accuracy: 0.8585 - val_loss: 0.7219 - val_accuracy: 0.6684
# Epoch 104/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3546 - accuracy: 0.8440 - val_loss: 0.6610 - val_accuracy: 0.6839
# Epoch 105/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3518 - accuracy: 0.8504 - val_loss: 0.6639 - val_accuracy: 0.6839
# Epoch 106/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3388 - accuracy: 0.8411 - val_loss: 0.6848 - val_accuracy: 0.6891
# Epoch 107/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3607 - accuracy: 0.8382 - val_loss: 0.6709 - val_accuracy: 0.6891
# Epoch 108/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3500 - accuracy: 0.8452 - val_loss: 0.7066 - val_accuracy: 0.6736
# Epoch 109/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3233 - accuracy: 0.8585 - val_loss: 0.7012 - val_accuracy: 0.6891
# Epoch 110/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3491 - accuracy: 0.8544 - val_loss: 0.7068 - val_accuracy: 0.6891
# Epoch 111/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3503 - accuracy: 0.8463 - val_loss: 0.6836 - val_accuracy: 0.7047
# Epoch 112/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3441 - accuracy: 0.8498 - val_loss: 0.7067 - val_accuracy: 0.6943
# Epoch 113/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3425 - accuracy: 0.8556 - val_loss: 0.7214 - val_accuracy: 0.7150
# Epoch 114/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3369 - accuracy: 0.8440 - val_loss: 0.6952 - val_accuracy: 0.6995
# Epoch 115/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3357 - accuracy: 0.8660 - val_loss: 0.7339 - val_accuracy: 0.6736
# Epoch 116/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3607 - accuracy: 0.8417 - val_loss: 0.6808 - val_accuracy: 0.7047
# Epoch 117/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3344 - accuracy: 0.8654 - val_loss: 0.7239 - val_accuracy: 0.7098
# Epoch 118/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3354 - accuracy: 0.8504 - val_loss: 0.7229 - val_accuracy: 0.6891
# Epoch 119/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3303 - accuracy: 0.8573 - val_loss: 0.7223 - val_accuracy: 0.6839
# Epoch 120/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3312 - accuracy: 0.8538 - val_loss: 0.7213 - val_accuracy: 0.6891
# Epoch 121/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3232 - accuracy: 0.8550 - val_loss: 0.6902 - val_accuracy: 0.6839
# Epoch 122/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3283 - accuracy: 0.8573 - val_loss: 0.6680 - val_accuracy: 0.6891
# Epoch 123/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3356 - accuracy: 0.8504 - val_loss: 0.6718 - val_accuracy: 0.6788
# Epoch 124/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3087 - accuracy: 0.8689 - val_loss: 0.6961 - val_accuracy: 0.6632
# Epoch 125/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3338 - accuracy: 0.8585 - val_loss: 0.7339 - val_accuracy: 0.6477
# Epoch 126/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3181 - accuracy: 0.8718 - val_loss: 0.7091 - val_accuracy: 0.6788
# Epoch 127/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3077 - accuracy: 0.8556 - val_loss: 0.7412 - val_accuracy: 0.6580
# Epoch 128/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3057 - accuracy: 0.8723 - val_loss: 0.7228 - val_accuracy: 0.6839
# Epoch 129/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3211 - accuracy: 0.8562 - val_loss: 0.7293 - val_accuracy: 0.6788
# Epoch 130/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3123 - accuracy: 0.8718 - val_loss: 0.7041 - val_accuracy: 0.6995
# Epoch 131/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3297 - accuracy: 0.8608 - val_loss: 0.7151 - val_accuracy: 0.6995
# Epoch 132/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3129 - accuracy: 0.8689 - val_loss: 0.6913 - val_accuracy: 0.6943
# Epoch 133/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3079 - accuracy: 0.8631 - val_loss: 0.7071 - val_accuracy: 0.6839
# Epoch 134/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3066 - accuracy: 0.8712 - val_loss: 0.7331 - val_accuracy: 0.6736
# Epoch 135/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3096 - accuracy: 0.8677 - val_loss: 0.6767 - val_accuracy: 0.6995
# Epoch 136/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3333 - accuracy: 0.8533 - val_loss: 0.6923 - val_accuracy: 0.6943
# Epoch 137/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3053 - accuracy: 0.8769 - val_loss: 0.7305 - val_accuracy: 0.6839
# Epoch 138/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3246 - accuracy: 0.8533 - val_loss: 0.7470 - val_accuracy: 0.6839
# Epoch 139/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3209 - accuracy: 0.8579 - val_loss: 0.7672 - val_accuracy: 0.6943
# Epoch 140/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3326 - accuracy: 0.8550 - val_loss: 0.7037 - val_accuracy: 0.6528
# Epoch 141/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2972 - accuracy: 0.8764 - val_loss: 0.7312 - val_accuracy: 0.6839
# Epoch 142/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3175 - accuracy: 0.8625 - val_loss: 0.6879 - val_accuracy: 0.6684
# Epoch 143/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2995 - accuracy: 0.8718 - val_loss: 0.7619 - val_accuracy: 0.6736
# Epoch 144/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2962 - accuracy: 0.8746 - val_loss: 0.7677 - val_accuracy: 0.6943
# Epoch 145/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2907 - accuracy: 0.8752 - val_loss: 0.7819 - val_accuracy: 0.6891
# Epoch 146/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3123 - accuracy: 0.8700 - val_loss: 0.7405 - val_accuracy: 0.7098
# Epoch 147/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3101 - accuracy: 0.8758 - val_loss: 0.6535 - val_accuracy: 0.7098
# Epoch 148/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3241 - accuracy: 0.8550 - val_loss: 0.6356 - val_accuracy: 0.7098
# Epoch 149/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3254 - accuracy: 0.8533 - val_loss: 0.6624 - val_accuracy: 0.7098
# Epoch 150/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3091 - accuracy: 0.8729 - val_loss: 0.6667 - val_accuracy: 0.6995
# Epoch 151/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3050 - accuracy: 0.8787 - val_loss: 0.6702 - val_accuracy: 0.7202
# Epoch 152/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3226 - accuracy: 0.8619 - val_loss: 0.6512 - val_accuracy: 0.7047
# Epoch 153/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2937 - accuracy: 0.8718 - val_loss: 0.6610 - val_accuracy: 0.7150
# Epoch 154/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2912 - accuracy: 0.8683 - val_loss: 0.6908 - val_accuracy: 0.7202
# Epoch 155/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2993 - accuracy: 0.8712 - val_loss: 0.6530 - val_accuracy: 0.6995
# Epoch 156/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2901 - accuracy: 0.8706 - val_loss: 0.6899 - val_accuracy: 0.6891
# Epoch 157/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3126 - accuracy: 0.8654 - val_loss: 0.6669 - val_accuracy: 0.6788
# Epoch 158/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3130 - accuracy: 0.8660 - val_loss: 0.6554 - val_accuracy: 0.6995
# Epoch 159/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2967 - accuracy: 0.8648 - val_loss: 0.6745 - val_accuracy: 0.7150
# Epoch 160/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3151 - accuracy: 0.8712 - val_loss: 0.6891 - val_accuracy: 0.6995
# Epoch 161/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2979 - accuracy: 0.8723 - val_loss: 0.6932 - val_accuracy: 0.6943
# Epoch 162/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3022 - accuracy: 0.8706 - val_loss: 0.7190 - val_accuracy: 0.6891
# Epoch 163/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2921 - accuracy: 0.8764 - val_loss: 0.7225 - val_accuracy: 0.6891
# Epoch 164/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.2869 - accuracy: 0.8804 - val_loss: 0.7353 - val_accuracy: 0.6891
# Epoch 165/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2863 - accuracy: 0.8845 - val_loss: 0.7333 - val_accuracy: 0.6839
# Epoch 166/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2909 - accuracy: 0.8821 - val_loss: 0.6851 - val_accuracy: 0.6891
# Epoch 167/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2787 - accuracy: 0.8804 - val_loss: 0.6824 - val_accuracy: 0.6839
# Epoch 168/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3014 - accuracy: 0.8700 - val_loss: 0.7020 - val_accuracy: 0.6788
# Epoch 169/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.2845 - accuracy: 0.8804 - val_loss: 0.7046 - val_accuracy: 0.6839
# Epoch 170/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.2673 - accuracy: 0.8845 - val_loss: 0.7016 - val_accuracy: 0.6995
# Epoch 171/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3143 - accuracy: 0.8683 - val_loss: 0.6314 - val_accuracy: 0.6995
# Epoch 172/200
# 87/87 [==============================] - 0s 6ms/step - loss: 0.2983 - accuracy: 0.8775 - val_loss: 0.6797 - val_accuracy: 0.6995
# Epoch 173/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.3080 - accuracy: 0.8706 - val_loss: 0.6707 - val_accuracy: 0.6995
# Epoch 174/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.2748 - accuracy: 0.8827 - val_loss: 0.7059 - val_accuracy: 0.6943
# Epoch 175/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.3014 - accuracy: 0.8775 - val_loss: 0.6540 - val_accuracy: 0.6995
# Epoch 176/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2658 - accuracy: 0.8925 - val_loss: 0.7127 - val_accuracy: 0.6839
# Epoch 177/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3174 - accuracy: 0.8723 - val_loss: 0.6573 - val_accuracy: 0.6891
# Epoch 178/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2913 - accuracy: 0.8798 - val_loss: 0.6494 - val_accuracy: 0.7047
# Epoch 179/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2936 - accuracy: 0.8752 - val_loss: 0.6789 - val_accuracy: 0.6943
# Epoch 180/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3098 - accuracy: 0.8683 - val_loss: 0.6827 - val_accuracy: 0.6943
# Epoch 181/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3142 - accuracy: 0.8712 - val_loss: 0.6792 - val_accuracy: 0.6891
# Epoch 182/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2938 - accuracy: 0.8845 - val_loss: 0.6709 - val_accuracy: 0.6995
# Epoch 183/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2841 - accuracy: 0.8856 - val_loss: 0.6891 - val_accuracy: 0.6736
# Epoch 184/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 0.8897 - val_loss: 0.6960 - val_accuracy: 0.6580
# Epoch 185/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3101 - accuracy: 0.8619 - val_loss: 0.6619 - val_accuracy: 0.7047
# Epoch 186/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2826 - accuracy: 0.8839 - val_loss: 0.6746 - val_accuracy: 0.7098
# Epoch 187/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3013 - accuracy: 0.8712 - val_loss: 0.6396 - val_accuracy: 0.6839
# Epoch 188/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2848 - accuracy: 0.8666 - val_loss: 0.6613 - val_accuracy: 0.6995
# Epoch 189/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2737 - accuracy: 0.8856 - val_loss: 0.6778 - val_accuracy: 0.6943
# Epoch 190/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.8798 - val_loss: 0.6894 - val_accuracy: 0.6839
# Epoch 191/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2775 - accuracy: 0.8781 - val_loss: 0.7177 - val_accuracy: 0.6943
# Epoch 192/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2578 - accuracy: 0.8885 - val_loss: 0.7501 - val_accuracy: 0.6839
# Epoch 193/200
# 87/87 [==============================] - 0s 6ms/step - loss: 0.2974 - accuracy: 0.8660 - val_loss: 0.7331 - val_accuracy: 0.6839
# Epoch 194/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3154 - accuracy: 0.8567 - val_loss: 0.6787 - val_accuracy: 0.6891
# Epoch 195/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2791 - accuracy: 0.8816 - val_loss: 0.6743 - val_accuracy: 0.6839
# Epoch 196/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3005 - accuracy: 0.8654 - val_loss: 0.6569 - val_accuracy: 0.6684
# Epoch 197/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2677 - accuracy: 0.8943 - val_loss: 0.7228 - val_accuracy: 0.6788
# Epoch 198/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2854 - accuracy: 0.8775 - val_loss: 0.6571 - val_accuracy: 0.7047
# Epoch 199/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2795 - accuracy: 0.8862 - val_loss: 0.6761 - val_accuracy: 0.7047
# Epoch 200/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.2804 - accuracy: 0.8850 - val_loss: 0.6507 - val_accuracy: 0.7098

# %%
# Сохранение/восстановление модели и выборок

model.save('/content/drive/MyDrive/Phone_calls/V3/model_data/model_audio_mean.h5')
with open('/content/drive/MyDrive/Phone_calls/V3/model_data/audio_train_val_mean.pickle', 'wb') as f:
    pickle.dump((x_train, y_train, x_val, y_val, x_scaler), f)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model = load_model('/content/drive/MyDrive/Phone_calls/V2/model_data/model_audio_mean.h5')
with open('/content/drive/MyDrive/Phone_calls/V2/model_data/audio_train_val_mean.pickle', 'rb') as f:
    x_train, y_train, x_val, y_val, x_scaler = pickle.load(f)

# %%
# Формирование тестовой выборки из файлов, не вошедших в основной набор

x_test, y_test = extract_data(FILE_INDEX_TRAIN_SPLIT, CLASS_FILES)
x_test = x_scaler.transform(x_test)
# Out:
# Жанр nontargets готов -> 680 c
# Жанр targets готов -> 929 c

# %%
# Функция оценки точности модели на заданной выборке

def eval_model(model,  # обученная модель нейронной сети
               x,      # входные данные
               y_true  # выходные данные (верные ответы)
               ):
    loss, acc = model.evaluate(x, y_true)
    print(f'Ошибка: {loss}, точность: {acc}')

    # Построение матрицы ошибок
    y_pred = model.predict(x)
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title('Матрица ошибок нормализованная')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASS_LIST)
    disp.plot(ax=ax)
    plt.show()

# %%
# Оценка точности сети на проверочной выборке
eval_model(model, x_val, y_val)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6507 - accuracy: 0.7098
# Ошибка: 0.6506989002227783, точность: 0.7098445892333984
# 7/7 [==============================] - 0s 2ms/step

# %%
# Оценка точности сети на тестовой выборке
eval_model(model, x_test, y_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2409 - accuracy: 0.9206
# Ошибка: 0.2409413754940033, точность: 0.9205607771873474
# 7/7 [==============================] - 0s 2ms/step

# %%
# Классификация файла и визуализация предсказания модели для него

def classify_file(model,        # обученная модель классификатора
                  x_scaler,     # настроенный нормировщих входных данных
                  class_index,  # верный индекс класса аудиофайла
                  file_index    # индекс (порядковый номер) аудиофайла в папке
                  ):
    # Подготовка выборки данных файла произведения
    song_name, file_x_data, file_y_data = process_file(class_index, file_index, DURATION_SEC)
    # Нормирование признаков уже настроенным нормировщиком
    file_x_data = x_scaler.transform(file_x_data)

    print('Файл:', song_name)
    print('Векторы для предсказания:', file_x_data.shape)

    # Вычисление предсказания по выборке
    predict = model.predict(file_x_data)
    # Определение среднего предсказания (голосование)
    predict_mean = predict.mean(axis=0)
    # Определение индекса класса по результату голосования
    predict_class_index = np.argmax(predict_mean)
    # Вычисление признака правильного предсказания
    predict_good = predict_class_index == class_index

    # Визуализация предсказания сети для файла
    plt.figure(figsize=(10,3))
    print('Классификация сети:', CLASS_LIST[predict_class_index], '-', 'ВЕРНО :-)' if predict_good else 'НЕВЕРНО.')
    plt.title('Среднее распределение векторов предсказаний')
    plt.bar(CLASS_LIST, predict_mean, color='g' if predict_good else 'r')
    plt.show()
    print('---------------------------------------------------------------')

    # Возврат результата предсказания
    return predict_class_index

# %%
# Классификация и визуализация нескольких файлов каждого класса

def classify_test_files(model,       # обученная модель классификатора
                        x_scaler,    # настроенный нормировщих входных данных
                        from_index,  # индекс аудиофайла, с которого начинать визуализацию
                        n_files):    # количество файлов для визуализации
    predict_all = 0
    predict_good = 0
    y_true = []
    y_pred = []
    for class_index in range(CLASS_COUNT):
        for file_index in range(from_index, from_index + n_files):
            predict_class_index = classify_file(model, x_scaler, class_index, file_index)
            y_true.append(class_index)
            y_pred.append(predict_class_index)
            predict_all += 1
            predict_good += (predict_class_index == class_index)

    # Расчет и вывод итогов классификации
    good_ratio = round(predict_good / predict_all * 100., 2)
    print(f'=== Обработано образцов: {predict_all}, из них распознано верно: {predict_good}, доля верных: {good_ratio}% ===')

    # Построение матрицы ошибок без нормализации, покажет попадания в штуках
    cm = confusion_matrix(y_true, y_pred)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title('Матрица ошибок по файлам аудио (не нормализованная)')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASS_LIST)
    disp.plot(ax=ax)
    plt.show()

# %%
# Визуализация классификации файлов из тренировочного набора
classify_test_files(model, x_scaler, 75, 10)
# Out:
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3062036223.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 30ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3065017744.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 28ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3060194234.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3064294212.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 32ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3073974450.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 32ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3059574503.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 28ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3064876767.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 43ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3074082170.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 29ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3074532960.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 32ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3061640783.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3014937828.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 33ms/step
# Классификация сети: nontargets - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/2991105797.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 99ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/2975582642.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/2989036463.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3009844652.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 30ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/2995443853.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 36ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/2986714873.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 33ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/2991724857.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/2984957195.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 37ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/2989730829.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# === Обработано образцов: 20, из них распознано верно: 19, доля верных: 95.0% ===

# %%
# Визуализация классификации файлов из тестового набора
classify_test_files(model, x_scaler, 990, 10)
# Out:
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3035314306.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 28ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3032483204.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 33ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3032207796.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 51ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3037744908.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3031429591.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 29ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3037654279.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 29ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3032951320.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 37ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3035284684.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 33ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3029730813.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 29ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/nontargets/3029390475.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: nontargets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3030815699.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 30ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3031466787.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 36ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3030619720.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 37ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3030974296.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3029638181.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 30ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3035810061.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 27ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3034668143.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 28ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3033343631.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 30ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3032179333.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 35ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: /content/drive/MyDrive/Phone_calls/V3/subset_data/targets/3035009492.mp3
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 37ms/step
# Классификация сети: targets - ВЕРНО :-)
# ---------------------------------------------------------------
# === Обработано образцов: 20, из них распознано верно: 20, доля верных: 100.0% ===
