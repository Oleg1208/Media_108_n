# %%
from gdown.download_folder import download
import pandas as pd
import gdown
gdown. download(' https://drive.google.com/uc?id=1om_ZmC0GzLAqmKv0Q2mhs3i-g03ZGn_8')
# Out:
# Downloading...
# From:  https://drive.google.com/uc?id=1om_ZmC0GzLAqmKv0Q2mhs3i-g03ZGn_8
# To: /content/Headliner.csv
# 100%|██████████| 3.67M/3.67M [00:00<00:00, 178MB/s]
# 'Headliner.csv'

# %%
df = pd.read_csv('Headliner.csv', delimiter=';',  error_bad_lines=False, header = 4)
df
# Out:
# <ipython-input-6-e1d4672bb87d>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('Headliner.csv', delimiter=';',  error_bad_lines=False, header = 4)
# Skipping line 87: expected 72 fields, saw 76
# Skipping line 436: expected 72 fields, saw 76
# Skipping line 622: expected 72 fields, saw 76
# Skipping line 1770: expected 72 fields, saw 76
# Skipping line 1783: expected 72 fields, saw 76
# Skipping line 2110: expected 72 fields, saw 76
# Skipping line 4605: expected 72 fields, saw 76
#           Статус                       Тип         Дата и время  \
# 0       Принятый               Звонок ВАТС  2023-07-31 20:51:16
# 1       Принятый               Звонок ВАТС  2023-07-31 19:57:08
# 2       Принятый               Звонок ВАТС  2023-07-31 19:06:54
# 3     Потерянный               Звонок ВАТС  2023-07-31 17:52:01
# ...

# %%
df[['Номер абонента', 'Длительность звонка', 'Теги']]
# Out:
#       Номер абонента Длительность звонка  \
# 0       7.999002e+10            00:02:50
# 1       7.966201e+10            00:00:25
# 2       7.925784e+10            00:03:12
# 3       7.495746e+10            00:00:22
# 4       7.916771e+10            00:03:09
# ...              ...                 ...
# 4747    7.934400e+10            00:00:27
# 4748    7.917078e+10            00:05:20
# 4749    7.800512e+10            00:00:03
# 4750    7.977766e+10            00:08:33
# 4751    7.977766e+10            00:00:48
#
#                                                    Теги
# 0     Коммерческая недвижимость - запись на просмотр...
# 1                              спорный - нет соединения
# 2     Первичный целевой - 2 очередь - 3 очередь - 1-...
# 3                              спорный - нет соединения
# 4     интересуют скидки - Первичный целевой - 3 очер...
# ...                                                 ...
# 4747                           спорный - нет соединения
# ...

# %%
df[ df.Теги.str.contains('Первичный целевой')]
# Out:
#         Статус                       Тип         Дата и время  Номер абонента  \
# 2     Принятый               Звонок ВАТС  2023-07-31 19:06:54    7.925784e+10
# 4     Принятый  Динамический коллтрекинг  2023-07-31 17:31:22    7.916771e+10
# 10    Принятый               Звонок ВАТС  2023-07-31 16:09:04    7.926523e+10
# 33    Принятый               Звонок ВАТС  2023-07-31 12:29:04    7.903788e+10
# 49    Принятый               Звонок ВАТС  2023-07-30 12:31:46    7.985975e+10
# ...        ...                       ...                  ...             ...
# 4689  Принятый               Звонок ВАТС  2023-05-02 12:55:46    7.977915e+10
# 4691  Принятый               Звонок ВАТС  2023-05-02 11:39:10    7.915037e+10
# 4725  Принятый  Динамический коллтрекинг  2023-05-01 18:07:53    7.916568e+10
# 4732  Принятый  Динамический коллтрекинг  2023-05-01 15:19:49    7.926886e+10
# 4750  Принятый               Звонок ВАТС  2023-05-01 09:44:05    7.977766e+10
#
# ...

# %%
df.loc[(df.Теги.str.contains('Первичный целевой')),['Номер абонента', 'Длительность звонка', 'Теги']]
# Out:
#       Номер абонента Длительность звонка  \
# 2       7.925784e+10            00:03:12
# 4       7.916771e+10            00:03:09
# 10      7.926523e+10            00:02:49
# 33      7.903788e+10            00:03:58
# 49      7.985975e+10            00:11:58
# ...              ...                 ...
# 4689    7.977915e+10            00:07:10
# 4691    7.915037e+10            00:07:49
# 4725    7.916568e+10            00:02:42
# 4732    7.926886e+10            00:01:55
# 4750    7.977766e+10            00:08:33
#
#                                                    Теги
# 2     Первичный целевой - 2 очередь - 3 очередь - 1-...
# 4     интересуют скидки - Первичный целевой - 3 очер...
# 10               Первичный целевой - студия - 3 очередь
# 33    Лид - Первичный целевой - 2 очередь - 3 очеред...
# 49                Первичный целевой - 3 очередь - 2-ком
# ...                                                 ...
# 4689              Первичный целевой - 2 очередь - 2-ком
# ...
